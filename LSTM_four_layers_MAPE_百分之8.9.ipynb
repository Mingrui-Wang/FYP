# %% [markdown]
# <a href="https://colab.research.google.com/github/Mingrui-Wang/FYP/blob/master/LSTM_four_layers_MAPE_%E7%99%BE%E5%88%86%E4%B9%8B8.9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
# fix random seed for reproducibility
numpy.random.seed(7)

# %%
import os
from google.colab import drive
drive.mount('/content/drive')

path = "/content/drive/My Drive/FYP数据集/"
os.chdir(path)
os.listdir(path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['Line_100_day_winsorize.csv']

# %%
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# %matplotlib inline

# %%
# load the dataset
dataframe = read_csv('Line_100_day_winsorize.csv', usecols=[1], engine='python', skipfooter=3)
dataset = dataframe.values
# 将整型变为float
dataset = dataset.astype('float32')

plt.plot(dataset)
plt.show()

# %%
# X is the number of passengers at a given time (t) and Y is the number of passengers at the next time (t + 1).

# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)


# split into train and test sets
train_size = int(len(dataset) * 0.9)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
# use this function to prepare the train and test datasets for modeling
look_back = 8
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout,BatchNormalization
from keras.layers import LSTM
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import time
from keras import regularizers
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(128, activation='relu', return_sequences=True, input_shape=(1, look_back)))
model.add(BatchNormalization())
model.add(LSTM(128, activation='relu',return_sequences=True))  # 返回维度为 64 的向量序列
model.add(LSTM(128,activation='tanh'))  # 返回维度为 64 的单个向量

model.add(Dense(1,activation='linear',kernel_regularizer=regularizers.l2(0.001)))

#early_stopping = EarlyStopping(monitor='val_loss',
#                                min_delta=0,
#                                patience=5,
#                                verbose=1,
#                                mode='auto')

model.compile(loss='mean_squared_error', optimizer='adam')
history = model.fit(trainX, trainY, epochs=50, batch_size=12, validation_data=(testX, testY))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/50
# 30/30 [==============================] - 1s 27ms/step - loss: 0.0445 - val_loss: 0.1451
# Epoch 2/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0106 - val_loss: 0.1132
# Epoch 3/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0091 - val_loss: 0.1066
# Epoch 4/50
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0080 - val_loss: 0.1199
# Epoch 5/50
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0075 - val_loss: 0.1190
# Epoch 6/50
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0073 - val_loss: 0.1165
# Epoch 7/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0074 - val_loss: 0.1135
# Epoch 8/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0079 - val_loss: 0.1227
# Epoch 9/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0068 - val_loss: 0.1025
# Epoch 10/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0075 - val_loss: 0.0976
# Epoch 11/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0067 - val_loss: 0.1027
# Epoch 12/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0068 - val_loss: 0.1059
# Epoch 13/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0065 - val_loss: 0.0926
# Epoch 14/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0066 - val_loss: 0.1001
# Epoch 15/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0068 - val_loss: 0.0836
# Epoch 16/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0065 - val_loss: 0.0725
# Epoch 17/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0066 - val_loss: 0.0841
# Epoch 18/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0060 - val_loss: 0.0771
# Epoch 19/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0061 - val_loss: 0.0544
# Epoch 20/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0059 - val_loss: 0.0567
# Epoch 21/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0064 - val_loss: 0.0597
# Epoch 22/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0058 - val_loss: 0.0385
# Epoch 23/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0057 - val_loss: 0.0315
# Epoch 24/50
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0051 - val_loss: 0.0368
# Epoch 25/50
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0063 - val_loss: 0.0344
# Epoch 26/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0062 - val_loss: 0.0262
# Epoch 27/50
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0056 - val_loss: 0.0245
# Epoch 28/50
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0057 - val_loss: 0.0243
# Epoch 29/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0053 - val_loss: 0.0252
# Epoch 30/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0050 - val_loss: 0.0289
# Epoch 31/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0053 - val_loss: 0.0266
# Epoch 32/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0232
# Epoch 33/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0048 - val_loss: 0.0261
# Epoch 34/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0051 - val_loss: 0.0371
# Epoch 35/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0059 - val_loss: 0.0235
# Epoch 36/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0045 - val_loss: 0.0234
# Epoch 37/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0050 - val_loss: 0.0241
# Epoch 38/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0043 - val_loss: 0.0273
# Epoch 39/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0044 - val_loss: 0.0317
# Epoch 40/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0046 - val_loss: 0.0279
# Epoch 41/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0042 - val_loss: 0.0349
# Epoch 42/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0045 - val_loss: 0.0270
# Epoch 43/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0042 - val_loss: 0.0273
# Epoch 44/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0042 - val_loss: 0.0272
# Epoch 45/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0041 - val_loss: 0.0264
# Epoch 46/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0045 - val_loss: 0.0287
# Epoch 47/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0045 - val_loss: 0.0272
# Epoch 48/50
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0039 - val_loss: 0.0339
# Epoch 49/50
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0045 - val_loss: 0.0263
# Epoch 50/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0037 - val_loss: 0.0277

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# %%
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %%
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 604.00 RMSE
# Test Score: 1916.75 RMSE

# %%
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
import numpy as np
def mape(y_true, y_pred):
    return np.mean(np.abs((y_pred - y_true) / y_true))

trainScore = mape(trainY[0], trainPredict[:,0])
print('Train Score: %.2f MAPE' % (trainScore))
testScore = mape(testY[0], testPredict[:,0])
print('Test Score: %.2f MAPE' % (testScore))
# Out:
# Train Score: 0.08 MAPE
# Test Score: 0.21 MAPE

# %%
initial = np.append(trainY[0],testY[0])
predict = np.append(trainPredict[:,0],testPredict[:,0])
score = mape(initial,predict)
score
# Out:
# 0.08905288101344898
